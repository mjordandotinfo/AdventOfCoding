# %%
f = open("input.txt", "r")
total = 0
max = [0, 0, 0]
for line in f:
    
    if line != "\n":
        total += int(line)
    else:
        print(max, total)
        for i in range(len(max)):
            if total > max[i]:
                max[i] = total
            total = 0
            max.sort()
            break
            
for i in range(len(max)):
    if total > max[i]:
        max[i] = total
    total = 0
    max.sort()
    break

print(max)
total = 0
for i in range(len(max)):
    total += max[i]

print(total)

f.close()
# Out:
# [0, 0, 0] 47524
# [0, 0, 47524] 49482
# [0, 47524, 49482] 43975
# [43975, 47524, 49482] 42138
# [43975, 47524, 49482] 44278
# [44278, 47524, 49482] 48560
# [47524, 48560, 49482] 39740
# [47524, 48560, 49482] 44645
# [47524, 48560, 49482] 58295
# [48560, 49482, 58295] 44701
# [48560, 49482, 58295] 46833
# [48560, 49482, 58295] 35926
# [48560, 49482, 58295] 46032
# [48560, 49482, 58295] 39325
# [48560, 49482, 58295] 37946
# [48560, 49482, 58295] 55471
# [49482, 55471, 58295] 36770
# [49482, 55471, 58295] 52855
# [52855, 55471, 58295] 25705
# [52855, 55471, 58295] 56338
# [55471, 56338, 58295] 54135
# [55471, 56338, 58295] 39643
# [55471, 56338, 58295] 60183
# [56338, 58295, 60183] 56995
# [56995, 58295, 60183] 16745
# [56995, 58295, 60183] 49761
# [56995, 58295, 60183] 45957
# [56995, 58295, 60183] 32082
# [56995, 58295, 60183] 57805
# [57805, 58295, 60183] 57585
# [57805, 58295, 60183] 51163
# [57805, 58295, 60183] 50436
# [57805, 58295, 60183] 47162
# [57805, 58295, 60183] 60217
# ...
